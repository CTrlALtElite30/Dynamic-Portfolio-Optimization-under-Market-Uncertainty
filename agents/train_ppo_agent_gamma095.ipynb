# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.results_plotter import load_results # fixed - more columns error

# Import custom env
PROJECT_ROOT = "E:/project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from envs.trading_env_continuous import TradingEnvContinuous

# Paths
DATA_PATH = os.path.join(PROJECT_ROOT, "outputs", "datasets", "states_v1_single_asset.npz")
SAVE_DIR = os.path.join(PROJECT_ROOT, "outputs", "models", "ppo_continuous_gamma095")
LOG_DIR = os.path.join(PROJECT_ROOT, "outputs", "logs", "ppo_continuous_gamma095")

os.makedirs(SAVE_DIR, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)

# Load data
data = np.load(DATA_PATH)
X_train, X_val = data["X_train"], data["X_val"]
prices_train, prices_val = data["prices"][:len(X_train)], data["prices"][len(X_train):len(X_train)+len(X_val)]

# Create environments
train_env = DummyVecEnv([lambda: Monitor(TradingEnvContinuous(X_train, prices_train, reward_type="log_return"), LOG_DIR)])
val_env = DummyVecEnv([lambda: Monitor(TradingEnvContinuous(X_val, prices_val, reward_type="log_return"), LOG_DIR)])


# Callbacks
eval_callback = EvalCallback(
    val_env,
    best_model_save_path=SAVE_DIR,
    log_path=LOG_DIR,
    eval_freq=2000,
    deterministic=True,
    render=False
)

# Train PPO Agent

model = PPO(
    "MlpPolicy",
    train_env,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=256, # changed
    n_epochs=10,
    gamma=0.95, # changed
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01,
    verbose=1,
    tensorboard_log=LOG_DIR
)

print("Starting PPO training...")
model.learn(total_timesteps=20000, callback=eval_callback)
model.save(os.path.join(SAVE_DIR, "ppo_final"))
print(f"PPO Training done. Model saved to {SAVE_DIR}")


# Plot Training Rewards

results_file = os.path.join(LOG_DIR, "monitor.csv")
if os.path.exists(results_file):
    # load monitor.csv file
    df = load_results(LOG_DIR) # fixed error more columns more than 3

    # Convert to numeric safely
    df = df.apply(pd.to_numeric, errors="coerce")

    timesteps = df["l"].cumsum()
    rewards = df["r"]

    # --- Plot ---
    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, rewards, label="Episode Reward")
    plt.xlabel("Timestep")
    plt.ylabel("Reward")
    plt.title("PPO Training Rewards - For gamma095 (Continuous Env)")
    plt.legend()
    plt.grid(True)

    plot_path = os.path.join(LOG_DIR, "ppo_gamma095_training_rewards.png")
    plt.savefig(plot_path)
    print(f"PPO training reward plot saved to {plot_path}")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cpu device
# Starting PPO training...
# Logging to E:/project\outputs\logs\ppo_continuous_gamma095\PPO_1
# Eval num_timesteps=2000, episode_reward=0.01 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 182      |
# |    mean_reward     | 0.00573  |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | -0.072   |
# | time/              |          |
# |    fps             | 1068     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=0.16 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 0.16         |
# | time/                   |              |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0021127071 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -26.4        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0225      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00445     |
# |    std                  | 0.998        |
# |    value_loss           | 0.00477      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.207    |
# | time/              |          |
# |    fps             | 963      |
# |    iterations      | 2        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=0.49 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 0.493       |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.011649454 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.256      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.047      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.997       |
# |    value_loss           | 0.00185     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.688    |
# | time/              |          |
# |    fps             | 888      |
# |    iterations      | 3        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=0.77 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 0.767        |
# | time/                   |              |
# |    total_timesteps      | 8000         |
# | train/                  |              |
# |    approx_kl            | 0.0077041625 |
# |    clip_fraction        | 0.0881       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.262        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.036       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0146      |
# |    std                  | 0.986        |
# |    value_loss           | 0.00059      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.06     |
# | time/              |          |
# |    fps             | 756      |
# |    iterations      | 4        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=1.02 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.02         |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0069187162 |
# |    clip_fraction        | 0.0855       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.343        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0389      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0138      |
# |    std                  | 0.98         |
# |    value_loss           | 0.00196      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.36     |
# | time/              |          |
# |    fps             | 706      |
# |    iterations      | 5        |
# |    time_elapsed    | 14       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=1.19 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 1.19        |
# | time/                   |             |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.006197592 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0247     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0081     |
# |    std                  | 0.974       |
# |    value_loss           | 0.00188     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.77     |
# | time/              |          |
# |    fps             | 700      |
# |    iterations      | 6        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=1.26 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 1.26        |
# | time/                   |             |
# |    total_timesteps      | 14000       |
# | train/                  |             |
# |    approx_kl            | 0.008404529 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0244     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.956       |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2        |
# | time/              |          |
# |    fps             | 694      |
# |    iterations      | 7        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=1.34 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 1.34        |
# | time/                   |             |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.004973525 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.006      |
# |    std                  | 0.945       |
# |    value_loss           | 0.00248     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.33     |
# | time/              |          |
# |    fps             | 701      |
# |    iterations      | 8        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=1.36 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.36         |
# | time/                   |              |
# |    total_timesteps      | 18000        |
# | train/                  |              |
# |    approx_kl            | 0.0055684256 |
# |    clip_fraction        | 0.0587       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.603        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0134      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00472     |
# |    std                  | 0.941        |
# |    value_loss           | 0.00214      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.53     |
# | time/              |          |
# |    fps             | 696      |
# |    iterations      | 9        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=1.38 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.38         |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0020117261 |
# |    clip_fraction        | 0.00908      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.619        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00983     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0015      |
# |    std                  | 0.931        |
# |    value_loss           | 0.00241      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.73     |
# | time/              |          |
# |    fps             | 704      |
# |    iterations      | 10       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 20480    |
# ---------------------------------
# PPO Training done. Model saved to E:/project\outputs\models\ppo_continuous_gamma095
# PPO training reward plot saved to E:/project\outputs\logs\ppo_continuous_gamma095\ppo_gamma095_training_rewards.png
