# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv

# Import custom env
PROJECT_ROOT = "E:/project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from envs.trading_env_continuous import TradingEnvContinuous

# Paths
DATA_PATH = os.path.join(PROJECT_ROOT, "outputs", "datasets", "states_v1_single_asset.npz")
SAVE_DIR = os.path.join(PROJECT_ROOT, "outputs", "models", "ppo_continuous")
LOG_DIR = os.path.join(PROJECT_ROOT, "outputs", "logs", "ppo_continuous")

os.makedirs(SAVE_DIR, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)

# Load data
data = np.load(DATA_PATH)
X_train, X_val = data["X_train"], data["X_val"]
prices_train, prices_val = data["prices"][:len(X_train)], data["prices"][len(X_train):len(X_train)+len(X_val)]

# Create environments
train_env = DummyVecEnv([lambda: Monitor(TradingEnvContinuous(X_train, prices_train, reward_type="log_return"), LOG_DIR)])
val_env = DummyVecEnv([lambda: Monitor(TradingEnvContinuous(X_val, prices_val, reward_type="log_return"), LOG_DIR)])


# Callbacks
eval_callback = EvalCallback(
    val_env,
    best_model_save_path=SAVE_DIR,
    log_path=LOG_DIR,
    eval_freq=2000,
    deterministic=True,
    render=False
)

# Train PPO Agent

model = PPO(
    "MlpPolicy",
    train_env,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01,
    verbose=1,
    tensorboard_log=LOG_DIR
)


print("Starting PPO training...")
model.learn(total_timesteps=20000, callback=eval_callback)
model.save(os.path.join(SAVE_DIR, "ppo_final"))
print(f"PPO Training done. Model saved to {SAVE_DIR}")


# Plot Training Rewards

results_file = os.path.join(LOG_DIR, "monitor.csv")
if os.path.exists(results_file):
    # Read raw CSV skipping metadata lines
    df = pd.read_csv(results_file, skiprows=2, header=None)

    print("Raw monitor.csv preview:")
    print(df.head())

    # Some versions merge values into a single string like "0-0.159169"
    # Try splitting if needed
    if df.shape[1] == 1:  # only one column (bad parse)
        df = df[0].str.split(",", expand=True)

    # Now df should have at least 2 columns: reward + length
    # We'll assume: col0 = reward, col1 = episode_length
    df = df.rename(columns={0: "r", 1: "l", 2: "t"})

    # Convert to numeric safely
    df = df.apply(pd.to_numeric, errors="coerce")

    timesteps = df["l"].cumsum()
    rewards = df["r"]

    # --- Plot ---
    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, rewards, label="Episode Reward")
    plt.xlabel("Timestep")
    plt.ylabel("Reward")
    plt.title("PPO Training Rewards (Continuous Env)")
    plt.legend()
    plt.grid(True)

    plot_path = os.path.join(LOG_DIR, "ppo_training_rewards.png")
    plt.savefig(plot_path)
    print(f"PPO training reward plot saved to {plot_path}")
    # plt.close() # cause i want to see here also.
else:
    print("Warning: monitor.csv not found, no reward plot generated.")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cpu device
# Starting PPO training...
# Logging to E:/project\outputs\logs\ppo_continuous\PPO_1
# Eval num_timesteps=2000, episode_reward=-0.01 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 182      |
# |    mean_reward     | -0.00762 |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.00539  |
# | time/              |          |
# |    fps             | 978      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=0.06 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 0.0628       |
# | time/                   |              |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0019382981 |
# |    clip_fraction        | 0.00679      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -13.3        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0255      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000707    |
# |    std                  | 1.02         |
# |    value_loss           | 0.00187      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.162    |
# | time/              |          |
# |    fps             | 669      |
# |    iterations      | 2        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=0.40 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 0.402       |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.010171318 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0212     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 1.03        |
# |    value_loss           | 0.00137     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.407    |
# | time/              |          |
# |    fps             | 619      |
# |    iterations      | 3        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=0.70 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 0.697       |
# | time/                   |             |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.008122022 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.015      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 1.04        |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.805    |
# | time/              |          |
# |    fps             | 552      |
# |    iterations      | 4        |
# |    time_elapsed    | 14       |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=0.93 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 0.927        |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0075616124 |
# |    clip_fraction        | 0.08         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.364        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0364      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0111      |
# |    std                  | 1.03         |
# |    value_loss           | 0.00304      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.14     |
# | time/              |          |
# |    fps             | 485      |
# |    iterations      | 5        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=1.14 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 1.14        |
# | time/                   |             |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.007276997 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00713    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00863    |
# |    std                  | 1.02        |
# |    value_loss           | 0.00374     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.54     |
# | time/              |          |
# |    fps             | 451      |
# |    iterations      | 6        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=1.31 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.31         |
# | time/                   |              |
# |    total_timesteps      | 14000        |
# | train/                  |              |
# |    approx_kl            | 0.0062809475 |
# |    clip_fraction        | 0.054        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.361        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0266      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00738     |
# |    std                  | 0.984        |
# |    value_loss           | 0.00453      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.8      |
# | time/              |          |
# |    fps             | 430      |
# |    iterations      | 7        |
# |    time_elapsed    | 33       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=1.37 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.37         |
# | time/                   |              |
# |    total_timesteps      | 16000        |
# | train/                  |              |
# |    approx_kl            | 0.0051104156 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.448        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0132      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00643     |
# |    std                  | 0.973        |
# |    value_loss           | 0.00758      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.18     |
# | time/              |          |
# |    fps             | 416      |
# |    iterations      | 8        |
# |    time_elapsed    | 39       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=1.42 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.42         |
# | time/                   |              |
# |    total_timesteps      | 18000        |
# | train/                  |              |
# |    approx_kl            | 0.0060603986 |
# |    clip_fraction        | 0.0628       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.465        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0301      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00643     |
# |    std                  | 0.943        |
# |    value_loss           | 0.00861      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.4      |
# | time/              |          |
# |    fps             | 404      |
# |    iterations      | 9        |
# |    time_elapsed    | 45       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=1.46 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.46         |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0070647956 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.51         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.016       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00347     |
# |    std                  | 0.941        |
# |    value_loss           | 0.0112       |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.59     |
# | time/              |          |
# |    fps             | 396      |
# |    iterations      | 10       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 20480    |
# ---------------------------------
# PPO Training done. Model saved to E:/project\outputs\models\ppo_continuous
# Raw monitor.csv preview:
#           0    1          2
# 0 -0.007624  182   3.814541
# 1 -0.007624  182   3.906957
# 2  0.010768  856   6.548050
# 3  0.625732  856   7.232804
# 4  0.321270  856  10.281797
# PPO training reward plot saved to E:/project\outputs\logs\ppo_continuous\ppo_training_rewards.png
