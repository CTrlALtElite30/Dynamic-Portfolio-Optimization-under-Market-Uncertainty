# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.results_plotter import load_results # fixed - more columns error

# Import custom env
PROJECT_ROOT = "E:/project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from envs.trading_env_continuous import TradingEnvContinuous

# Paths
DATA_PATH = os.path.join(PROJECT_ROOT, "outputs", "datasets", "states_v1_single_asset.npz")
SAVE_DIR = os.path.join(PROJECT_ROOT, "outputs", "models", "ppo_continuous_gamma095")
LOG_DIR = os.path.join(PROJECT_ROOT, "outputs", "logs", "ppo_continuous_gamma095")

os.makedirs(SAVE_DIR, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)

# Load data
data = np.load(DATA_PATH)
X_train, X_val = data["X_train"], data["X_val"]
prices_train, prices_val = data["prices"][:len(X_train)], data["prices"][len(X_train):len(X_train)+len(X_val)]

# Create environments
train_env = DummyVecEnv([lambda: Monitor(TradingEnvContinuous(X_train, prices_train, reward_type="log_return"), LOG_DIR)])
val_env = DummyVecEnv([lambda: Monitor(TradingEnvContinuous(X_val, prices_val, reward_type="log_return"), LOG_DIR)])


# Callbacks
eval_callback = EvalCallback(
    val_env,
    best_model_save_path=SAVE_DIR,
    log_path=LOG_DIR,
    eval_freq=2000,
    deterministic=True,
    render=False
)

# Train PPO Agent

model = PPO(
    "MlpPolicy",
    train_env,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=256, # changed
    n_epochs=10,
    gamma=0.95, # changed
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01,
    verbose=1,
    tensorboard_log=LOG_DIR
)

print("Starting PPO training...")
model.learn(total_timesteps=20000, callback=eval_callback)
model.save(os.path.join(SAVE_DIR, "ppo_final"))
print(f"PPO Training done. Model saved to {SAVE_DIR}")


# Plot Training Rewards

results_file = os.path.join(LOG_DIR, "monitor.csv")
if os.path.exists(results_file):
    # load monitor.csv file
    df = load_results(LOG_DIR) # fixed error more columns more than 3

    # Convert to numeric safely
    df = df.apply(pd.to_numeric, errors="coerce")

    timesteps = df["l"].cumsum()
    rewards = df["r"]

    # --- Plot ---
    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, rewards, label="Episode Reward")
    plt.xlabel("Timestep")
    plt.ylabel("Reward")
    plt.title("PPO Training Rewards - For gamma095 (Continuous Env)")
    plt.legend()
    plt.grid(True)

    plot_path = os.path.join(LOG_DIR, "ppo_gamma095_training_rewards.png")
    plt.savefig(plot_path)
    print(f"PPO training reward plot saved to {plot_path}")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cpu device
# Starting PPO training...
# Logging to E:/project\outputs\logs\ppo_continuous_gamma095\PPO_8
# Eval num_timesteps=2000, episode_reward=-0.00 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 182      |
# |    mean_reward     | -0.00404 |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | -0.171   |
# | time/              |          |
# |    fps             | 1004     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=0.17 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 0.169        |
# | time/                   |              |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0031844275 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -2.99        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00859     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00458     |
# |    std                  | 1.02         |
# |    value_loss           | 0.00351      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.039    |
# | time/              |          |
# |    fps             | 835      |
# |    iterations      | 2        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=0.41 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 0.411        |
# | time/                   |              |
# |    total_timesteps      | 6000         |
# | train/                  |              |
# |    approx_kl            | 0.0063489517 |
# |    clip_fraction        | 0.0675       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.296       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0101      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0117      |
# |    std                  | 1.02         |
# |    value_loss           | 0.00153      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.489    |
# | time/              |          |
# |    fps             | 786      |
# |    iterations      | 3        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=0.70 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 182        |
# |    mean_reward          | 0.697      |
# | time/                   |            |
# |    total_timesteps      | 8000       |
# | train/                  |            |
# |    approx_kl            | 0.01001269 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0.3        |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0511    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0176    |
# |    std                  | 1.02       |
# |    value_loss           | 0.000873   |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.86     |
# | time/              |          |
# |    fps             | 786      |
# |    iterations      | 4        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=0.92 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 0.916       |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.006208282 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0342     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.01        |
# |    value_loss           | 0.00116     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.18     |
# | time/              |          |
# |    fps             | 776      |
# |    iterations      | 5        |
# |    time_elapsed    | 13       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=1.13 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 1.13        |
# | time/                   |             |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.006433768 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00783    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 1           |
# |    value_loss           | 0.00141     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.58     |
# | time/              |          |
# |    fps             | 768      |
# |    iterations      | 6        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=1.24 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.24         |
# | time/                   |              |
# |    total_timesteps      | 14000        |
# | train/                  |              |
# |    approx_kl            | 0.0047425404 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.497        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0215      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0078      |
# |    std                  | 0.992        |
# |    value_loss           | 0.00212      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.87     |
# | time/              |          |
# |    fps             | 760      |
# |    iterations      | 7        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=1.33 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.33         |
# | time/                   |              |
# |    total_timesteps      | 16000        |
# | train/                  |              |
# |    approx_kl            | 0.0061648176 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0224      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0075      |
# |    std                  | 0.972        |
# |    value_loss           | 0.00367      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.25     |
# | time/              |          |
# |    fps             | 762      |
# |    iterations      | 8        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=1.39 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 1.39        |
# | time/                   |             |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.004755252 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0125     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00496    |
# |    std                  | 0.96        |
# |    value_loss           | 0.00281     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.46     |
# | time/              |          |
# |    fps             | 766      |
# |    iterations      | 9        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=1.42 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 182        |
# |    mean_reward          | 1.42       |
# | time/                   |            |
# |    total_timesteps      | 20000      |
# | train/                  |            |
# |    approx_kl            | 0.00605166 |
# |    clip_fraction        | 0.0489     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.587      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0186    |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00434   |
# |    std                  | 0.954      |
# |    value_loss           | 0.00329    |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.65     |
# | time/              |          |
# |    fps             | 768      |
# |    iterations      | 10       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 20480    |
# ---------------------------------
# PPO Training done. Model saved to E:/project\outputs\models\ppo_continuous_gamma095
# PPO training reward plot saved to E:/project\outputs\logs\ppo_continuous_gamma095\ppo_gamma095_training_rewards.png
