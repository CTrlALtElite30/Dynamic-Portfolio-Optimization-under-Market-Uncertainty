# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv

# Import custom env
PROJECT_ROOT = "E:/project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from envs.trading_env_continuous import TradingEnvContinuous

# Paths
DATA_PATH = os.path.join(PROJECT_ROOT, "outputs", "datasets", "states_v1_single_asset.npz")
SAVE_DIR = os.path.join(PROJECT_ROOT, "outputs", "models", "ppo_continuous")
LOG_DIR = os.path.join(PROJECT_ROOT, "outputs", "logs", "ppo_continuous")

os.makedirs(SAVE_DIR, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)

# Load data
data = np.load(DATA_PATH)
X_train, X_val = data["X_train"], data["X_val"]
prices_train, prices_val = data["prices"][:len(X_train)], data["prices"][len(X_train):len(X_train)+len(X_val)]

# Create environments
train_env = DummyVecEnv([lambda: Monitor(TradingEnvContinuous(X_train, prices_train, reward_type="log_return"), LOG_DIR)])
val_env = DummyVecEnv([lambda: Monitor(TradingEnvContinuous(X_val, prices_val, reward_type="log_return"), LOG_DIR)])


# Callbacks
eval_callback = EvalCallback(
    val_env,
    best_model_save_path=SAVE_DIR,
    log_path=LOG_DIR,
    eval_freq=2000,
    deterministic=True,
    render=False
)

# Train PPO Agent

model = PPO(
    "MlpPolicy",
    train_env,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01,
    verbose=1,
    tensorboard_log=LOG_DIR
)


print("Starting PPO training...")
model.learn(total_timesteps=20000, callback=eval_callback)
model.save(os.path.join(SAVE_DIR, "ppo_final"))
print(f"PPO Training done. Model saved to {SAVE_DIR}")


# Plot Training Rewards

results_file = os.path.join(LOG_DIR, "monitor.csv")
if os.path.exists(results_file):
    # Read raw CSV skipping metadata lines
    df = pd.read_csv(results_file, skiprows=2, header=None)

    print("Raw monitor.csv preview:")
    print(df.head())

    # Some versions merge values into a single string like "0-0.159169"
    # Try splitting if needed
    if df.shape[1] == 1:  # only one column (bad parse)
        df = df[0].str.split(",", expand=True)

    # Now df should have at least 2 columns: reward + length
    # We'll assume: col0 = reward, col1 = episode_length
    df = df.rename(columns={0: "r", 1: "l", 2: "t"})

    # Convert to numeric safely
    df = df.apply(pd.to_numeric, errors="coerce")

    timesteps = df["l"].cumsum()
    rewards = df["r"]

    # --- Plot ---
    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, rewards, label="Episode Reward")
    plt.xlabel("Timestep")
    plt.ylabel("Reward")
    plt.title("PPO Training Rewards (Continuous Env)")
    plt.legend()
    plt.grid(True)

    plot_path = os.path.join(LOG_DIR, "ppo_training_rewards.png")
    plt.savefig(plot_path)
    print(f"PPO training reward plot saved to {plot_path}")
    # plt.close() # cause i want to see here also.
else:
    print("Warning: monitor.csv not found, no reward plot generated.")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cpu device
# Starting PPO training...
# Logging to E:/project\outputs\logs\ppo_continuous\PPO_6
# Eval num_timesteps=2000, episode_reward=-0.01 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 182      |
# |    mean_reward     | -0.00539 |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | -0.104   |
# | time/              |          |
# |    fps             | 885      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Eval num_timesteps=4000, episode_reward=0.08 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 0.0792       |
# | time/                   |              |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0033759014 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -16.8        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0226      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00154     |
# |    std                  | 1.01         |
# |    value_loss           | 0.00212      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | -0.14    |
# | time/              |          |
# |    fps             | 669      |
# |    iterations      | 2        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6000, episode_reward=0.37 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 0.366       |
# | time/                   |             |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.009755243 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -0.096      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0655     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 1.02        |
# |    value_loss           | 0.0014      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.432    |
# | time/              |          |
# |    fps             | 611      |
# |    iterations      | 3        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=0.64 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 0.636       |
# | time/                   |             |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.006839926 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -0.0948     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0455     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.999       |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 0.713    |
# | time/              |          |
# |    fps             | 582      |
# |    iterations      | 4        |
# |    time_elapsed    | 14       |
# |    total_timesteps | 8192     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=0.89 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 0.886       |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.007546025 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00289     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.981       |
# |    value_loss           | 0.00383     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 563      |
# |    iterations      | 5        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 10240    |
# ---------------------------------
# Eval num_timesteps=12000, episode_reward=1.09 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 1.09        |
# | time/                   |             |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.006633932 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0187     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00917    |
# |    std                  | 0.957       |
# |    value_loss           | 0.00372     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.43     |
# | time/              |          |
# |    fps             | 554      |
# |    iterations      | 6        |
# |    time_elapsed    | 22       |
# |    total_timesteps | 12288    |
# ---------------------------------
# Eval num_timesteps=14000, episode_reward=1.31 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 182        |
# |    mean_reward          | 1.31       |
# | time/                   |            |
# |    total_timesteps      | 14000      |
# | train/                  |            |
# |    approx_kl            | 0.01001529 |
# |    clip_fraction        | 0.0877     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.449      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0319    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00857   |
# |    std                  | 0.933      |
# |    value_loss           | 0.00596    |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 1.71     |
# | time/              |          |
# |    fps             | 545      |
# |    iterations      | 7        |
# |    time_elapsed    | 26       |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16000, episode_reward=1.36 +/- 0.00
# Episode length: 182.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 182         |
# |    mean_reward          | 1.36        |
# | time/                   |             |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.006202552 |
# |    clip_fraction        | 0.0655      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00595    |
# |    std                  | 0.913       |
# |    value_loss           | 0.00923     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.08     |
# | time/              |          |
# |    fps             | 517      |
# |    iterations      | 8        |
# |    time_elapsed    | 31       |
# |    total_timesteps | 16384    |
# ---------------------------------
# Eval num_timesteps=18000, episode_reward=1.38 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.38         |
# | time/                   |              |
# |    total_timesteps      | 18000        |
# | train/                  |              |
# |    approx_kl            | 0.0016715891 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.501        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0155      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000947    |
# |    std                  | 0.899        |
# |    value_loss           | 0.00554      |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.31     |
# | time/              |          |
# |    fps             | 510      |
# |    iterations      | 9        |
# |    time_elapsed    | 36       |
# |    total_timesteps | 18432    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=1.41 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 182          |
# |    mean_reward          | 1.41         |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0044240793 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.49         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.016       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00339     |
# |    std                  | 0.882        |
# |    value_loss           | 0.0105       |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 856      |
# |    ep_rew_mean     | 2.52     |
# | time/              |          |
# |    fps             | 484      |
# |    iterations      | 10       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 20480    |
# ---------------------------------
# PPO Training done. Model saved to E:/project\outputs\models\ppo_continuous
# Raw monitor.csv preview:
#           0    1          2
# 0 -0.005389  182   3.872136
# 1 -0.005389  182   3.964893
# 2 -0.449277  856   6.591417
# 3  0.097244  856   7.185800
# 4  0.616341  856  10.071717
# PPO training reward plot saved to E:/project\outputs\logs\ppo_continuous\ppo_training_rewards.png
