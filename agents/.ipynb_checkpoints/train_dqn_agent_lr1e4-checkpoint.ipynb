# %%
# final dqn train compateble with SB3 che with output : 
# .zip file bayni che \models\dqn_discrete_lr1e4\ ma: 
import os, sys, numpy as np, matplotlib.pyplot as plt
import pandas as pd
from stable_baselines3 import DQN
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor
from stable_baselines3.common.env_util import make_vec_env

PROJECT_ROOT = r"E:/project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from envs.trading_env_discrete import TradingEnvDiscrete

# Paths
DATA_PATH = os.path.join(PROJECT_ROOT, "outputs", "datasets", "states_v1_single_asset.npz")
SAVE_DIR  = os.path.join(PROJECT_ROOT, "outputs", "models", "dqn_discrete_lr1e4")
LOG_DIR   = os.path.join(PROJECT_ROOT, "outputs", "logs", "dqn_discrete_lr1e4")
os.makedirs(SAVE_DIR, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)

# Load data
data = np.load(DATA_PATH)
X_train, X_val = data["X_train"], data["X_val"]
prices = data["prices"]
prices_train = prices[:len(X_train)]
prices_val   = prices[len(X_train):len(X_train)+len(X_val)]

# Make vec envs (NO Monitor here)
def make_train():
    return TradingEnvDiscrete(X_train, prices_train, reward_type="log_return")

def make_val():
    return TradingEnvDiscrete(X_val, prices_val, reward_type="log_return")

train_env = make_vec_env(make_train, n_envs=1, seed=42, vec_env_cls=DummyVecEnv)
val_env   = make_vec_env(make_val,   n_envs=1, seed=43, vec_env_cls=DummyVecEnv)

# Wrap with VecMonitor to record monitor.csv correctly
train_env = VecMonitor(train_env, LOG_DIR)
val_env   = VecMonitor(val_env,   LOG_DIR)

# Callback
eval_callback = EvalCallback(
    val_env,
    best_model_save_path=SAVE_DIR,
    log_path=LOG_DIR,
    eval_freq=2000,
    deterministic=True,
    render=False
)

# Train DQN Agent
model = DQN(
    "MlpPolicy",
    train_env,
    learning_rate=1e-4,
    buffer_size=100000,
    learning_starts=1000,
    batch_size=32,
    tau=1.0,
    gamma=0.99,
    train_freq=4,
    target_update_interval=1000,
    exploration_fraction=0.1,
    exploration_final_eps=0.02,
    verbose=1,
    tensorboard_log=LOG_DIR,
)


print("Starting training...")
model.learn(total_timesteps=20000, callback=eval_callback)
model.save(os.path.join(SAVE_DIR, "dqn_final"))
print(f"Training done. Model saved to {SAVE_DIR}")

# Plot Training Rewards

results_file = os.path.join(LOG_DIR, "monitor.csv")
if os.path.exists(results_file):
    # SB3 monitor.csv has comment lines starting with '#'
    df = pd.read_csv(results_file, skiprows=1)
    # df contains columns like "r", "l", "t"
    timesteps = df["l"].cumsum()   # episode lengths → cumulative timesteps
    rewards = df["r"]              # episode rewards

    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, rewards, label="Episode Reward")
    plt.xlabel("Timestep")
    plt.ylabel("Reward")
    plt.title("DQN Training Rewards For lr1e4 (Discrete Env)")
    plt.legend()
    plt.grid(True)
    plot_path = os.path.join(LOG_DIR, "dqn_training_lr1e4_rewards.png")
    plt.savefig(plot_path, dpi=150, bbox_inches="tight")
    print(f"Training reward plot saved to {plot_path}")
else:
    print("Warning: monitor.csv not found, no reward plot generated.")
# Out:
# Using cpu device
# Starting training...
# Logging to E:/project\outputs\logs\dqn_discrete_lr1e4\DQN_3
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\stable_baselines3\common\vec_env\vec_monitor.py:44: UserWarning: The environment is already wrapped with a `Monitor` wrapperbut you are wrapping it with a `VecMonitor` wrapper, the `Monitor` statistics will beoverwritten by the `VecMonitor` ones.
#   warnings.warn(
# Eval num_timesteps=2000, episode_reward=-0.03 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 182      |
# |    mean_reward      | -0.0331  |
# | rollout/            |          |
# |    exploration_rate | 0.0205   |
# | time/               |          |
# |    total_timesteps  | 2000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000187 |
# |    n_updates        | 249      |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 856      |
# |    ep_rew_mean      | 0.277    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 835      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3424     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.93e-05 |
# |    n_updates        | 605      |
# ----------------------------------
# Eval num_timesteps=4000, episode_reward=-0.05 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 182      |
# |    mean_reward      | -0.0496  |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.97e-05 |
# |    n_updates        | 749      |
# ----------------------------------
# Eval num_timesteps=6000, episode_reward=-0.01 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 182      |
# |    mean_reward      | -0.0134  |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 6000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39e-05 |
# |    n_updates        | 1249     |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 856      |
# |    ep_rew_mean      | 0.294    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 663      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6848     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.31e-05 |
# |    n_updates        | 1461     |
# ----------------------------------
# Eval num_timesteps=8000, episode_reward=-0.02 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 182      |
# |    mean_reward      | -0.0237  |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.86e-06 |
# |    n_updates        | 1749     |
# ----------------------------------
# Eval num_timesteps=10000, episode_reward=0.01 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 182      |
# |    mean_reward      | 0.00745  |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 10000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.18e-05 |
# |    n_updates        | 2249     |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 856      |
# |    ep_rew_mean      | 0.318    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 651      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 10272    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02e-05 |
# |    n_updates        | 2317     |
# ----------------------------------
# Eval num_timesteps=12000, episode_reward=-0.03 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 182      |
# |    mean_reward      | -0.0306  |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88e-05 |
# |    n_updates        | 2749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 856      |
# |    ep_rew_mean      | 0.347    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 565      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 13696    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.41e-05 |
# |    n_updates        | 3173     |
# ----------------------------------
# Eval num_timesteps=14000, episode_reward=-0.08 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 182      |
# |    mean_reward      | -0.0829  |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 14000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17e-05 |
# |    n_updates        | 3249     |
# ----------------------------------
# Eval num_timesteps=16000, episode_reward=-0.03 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 182      |
# |    mean_reward      | -0.033   |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.13e-06 |
# |    n_updates        | 3749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 856      |
# |    ep_rew_mean      | 0.338    |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 512      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 17120    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15e-05 |
# |    n_updates        | 4029     |
# ----------------------------------
# Eval num_timesteps=18000, episode_reward=-0.06 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 182      |
# |    mean_reward      | -0.0637  |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 18000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.13e-05 |
# |    n_updates        | 4249     |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=-0.01 +/- 0.00
# Episode length: 182.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 182      |
# |    mean_reward      | -0.011   |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.04e-05 |
# |    n_updates        | 4749     |
# ----------------------------------
# Training done. Model saved to E:/project\outputs\models\dqn_discrete_lr1e4
# Training reward plot saved to E:/project\outputs\logs\dqn_discrete_lr1e4\dqn_training_lr1e4_rewards.png
